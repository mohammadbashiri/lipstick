# %%
import numpy as np

from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes
import matplotlib.pyplot as plt

# %%
def setup_axes(fig, rect):
    """
    A simple one.
    """
    tr = Affine2D().scale(2, 1).rotate_deg(60)

    grid_helper = floating_axes.GridHelperCurveLinear(
        tr, extremes=(-0.5, 3.5, 0, 4))

    ax1 = floating_axes.FloatingSubplot(fig, rect, grid_helper=grid_helper)
    fig.add_subplot(ax1)

    aux_ax = ax1.get_aux_axes(tr)

    grid_helper.grid_finder.grid_locator1._nbins = 4
    grid_helper.grid_finder.grid_locator2._nbins = 4

    return ax1, aux_ax

# %%
fig = plt.figure(figsize=(13, 3))

ax1, aux_ax1 = setup_axes(fig, 131)
aux_ax1.bar([0, 1, 2, 3], [3, 2, 1, 3])

# %%
a = plt.gca()

# %%
type(a)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lipstick import scatter_diag

# %%
fig, ax = plt.subplots(figsize=(3, 3), dpi=150)
scatter_diag(np.random.randn(100) * 100, np.random.randn(100) * 100, ax=ax, share_ticks=False)
sns.despine(trim=True)

# %%
fig, ax = plt.subplots(figsize=(3, 3), dpi=150)
scatter_diag(np.random.randn(100), np.random.randn(100), ax=ax, share_ticks=False)
sns.despine(trim=True)

# %%
layout = """
    A..B
    CDD.
    """
fig = plt.figure(constrained_layout=True)
ax_dict = fig.subplot_mosaic(layout)

# %%
import matplotlib.pyplot as plt
layout = """
    A.C
    ABB
    .D.
"""
ax_dict = plt.figure(constrained_layout=True).subplot_mosaic(layout)
